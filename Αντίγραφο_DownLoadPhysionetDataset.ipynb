# %% [markdown]
# <a href="https://colab.research.google.com/github/m1kemp/School-Hero/blob/main/%CE%91%CE%BD%CF%84%CE%AF%CE%B3%CF%81%CE%B1%CF%86%CE%BF_DownLoadPhysionetDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests

# URL of PhysioNet dataset
DATA_URL_PHYSIONET = "https://physionet.org/static/published-projects/challenge-2017/1.0.0/training2017.zip"
SAVE_PATH_PHYSIONET = "data/training2017.zip"

# URL of MIT-BIH dataset
DATA_URL_MITBIH = "https://physionet.org/static/published-projects/mitdb/mit-bih-arrhythmia-database-1.0.0.zip"
SAVE_PATH_MITBIH = "data/mit-bih-arrhythmia-database-1.0.0.zip"

def download_data(DATA_URL, SAVE_PATH):
    if not os.path.exists("data"):
        os.makedirs("data")

    print("Downloading dataset...")
    response = requests.get(DATA_URL, stream=True)

    with open(SAVE_PATH, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)

    print("Download complete! Unzipping...")
    os.system(f"unzip {SAVE_PATH} -d data/")
    print("Dataset is ready.")

    # Delete the zip file
    os.remove(SAVE_PATH)
    print(f"Deleted zip file: {SAVE_PATH}")

download_data(DATA_URL_PHYSIONET, SAVE_PATH_PHYSIONET)
download_data(DATA_URL_MITBIH, SAVE_PATH_MITBIH)
# Out:
# Downloading dataset...
# Download complete! Unzipping...
# Dataset is ready.
# Deleted zip file: data/training2017.zip
# Downloading dataset...
# Download complete! Unzipping...
# Dataset is ready.
# Deleted zip file: data/mit-bih-arrhythmia-database-1.0.0.zip

# %%
# !pip install wfdb
# !pip install neurokit2
# !pip install biosppy
# !pip install torch
# !pip install pickle
# !pip install gzip
# !pip install peakutils


import os
import numpy as np
import pandas as pd
import wfdb
import scipy.io
import scipy.signal
import neurokit2 as nk
import biosppy.signals.ecg as ecg
import torch
import pickle
import gzip

# Define constants
TARGET_SAMPLING_RATE = 125  # Hz
MAX_LEN_PHYSIONET = 10 * TARGET_SAMPLING_RATE  # 10 seconds
MAX_LEN_MITBIH = 30 * TARGET_SAMPLING_RATE  # 30 seconds

# Load PhysioNet dataset
def load_physionet_data(path):
    """Load PhysioNet 2017 dataset from .mat files and reference.csv."""
    signals, labels = [], []
    ref_df = pd.read_csv(os.path.join(path, "REFERENCE.csv"), header=None)
    ref_dict = dict(zip(ref_df[0], ref_df[1]))
    label_mapping = {"N": 0, "A": 1, "O": 2, "~": 3}  # Modify as per dataset classes


    for file in os.listdir(path):
        if file.endswith(".mat"):
            record_name = file.replace(".mat", "")
            mat_data = scipy.io.loadmat(os.path.join(path, file))
            signal = mat_data["val"][0]  # Extract ECG lead
            label = ref_dict.get(record_name, None)
            if label:
                signals.append(signal)
                physionet_labels = label_mapping[label]
                labels.append(physionet_labels)

    return signals, labels



# Downsampling function
def downsample_signal(signal, original_fs, target_fs=125):
    """Downsample ECG signal from original_fs to target_fs."""
    num_samples = int(len(signal) * target_fs / original_fs)
    return scipy.signal.resample(signal, num_samples)

# Normalize function
def normalize_signal(signal):
    """Normalize ECG signal between 0 and 1."""
    return (signal - np.min(signal)) / (np.max(signal) - np.min(signal))

# R-peak detection
def detect_r_peaks(signal, sampling_rate=125):
    """Detect R-peaks using the Pan-Tompkins algorithm."""
    _, r_peaks = nk.ecg_peaks(signal, sampling_rate=sampling_rate)
    return np.array(r_peaks["ECG_R_Peaks"])

# Beat segmentation
def extract_beats(signal, r_peaks, window_size=0.5, fs=125):
    """Extract ECG beats centered around R-peaks."""
    beat_length = int(window_size * fs)
    beats = []
    for peak in r_peaks:
        start = max(0, peak - beat_length)
        end = min(len(signal), peak + beat_length)
        beat = signal[start:end]
        beats.append(beat)
    return beats

# Zero-padding
def pad_signal(signal, max_len=MAX_LEN_PHYSIONET):
    """Pad signal to max_len with zeros."""
    if len(signal) < max_len:
        return np.pad(signal, (0, max_len - len(signal)), 'constant')
    else:
        return signal[:max_len]

# Full preprocessing pipeline
def preprocess_ecg_dataset(dataset_path):
    """Preprocess ECG dataset from PhysioNet or MIT-BIH."""
    signals, labels = load_physionet_data(dataset_path)
    original_fs = 300  # PhysioNet signals are sampled at 300 Hz
    max_len = MAX_LEN_PHYSIONET
    processed_signals,processed_labels = [],[]
    for signal,label in zip(signals,labels):
        # 1. Downsampling
        signal = downsample_signal(signal, original_fs, TARGET_SAMPLING_RATE)
        # 2. Normalization
        signal = normalize_signal(signal)
        # 3. R-peak detection
        r_peaks = detect_r_peaks(signal, TARGET_SAMPLING_RATE)
        # 4. Beat extraction
        beats = extract_beats(signal, r_peaks)
        # 5. Zero-padding each beat
        padded_beats = [pad_signal(beat, max_len) for beat in beats]
        processed_signals.extend(padded_beats)  # Collect all beats
        processed_labels.extend([label] * len(padded_beats))  # Assign the same label to all extracted beats

    return np.array(processed_signals), np.array(processed_labels)

# Example Usage
physionet_data, physionet_labels = preprocess_ecg_dataset("data/training2017")

# Convert to PyTorch Tensors
X_physionet = torch.tensor(physionet_data, dtype=torch.float32)
y_physionet = torch.tensor(physionet_labels, dtype=torch.long)

#save the processed data
# Save data with gzip compression
with gzip.open("pretraining_data.pkl.gz", "wb") as f:
    pickle.dump((X_physionet, y_physionet), f)



print(f"PhysioNet Data Shape: {X_physionet.shape}")
# Out:
# Collecting wfdb
#   Downloading wfdb-4.2.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.0.2)
# Collecting pandas>=2.2.3 (from wfdb)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (1.14.1)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.8.1->wfdb) (2025.1.31)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Downloading wfdb-4.2.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.3/162.3 kB 7.0 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 110.9 MB/s eta 0:00:00
# Installing collected packages: pandas, wfdb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed pandas-2.2.3 wfdb-4.2.0
# Collecting neurokit2
#   Downloading neurokit2-0.2.10-py2.py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neurokit2) (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from neurokit2) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from neurokit2) (3.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->neurokit2) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neurokit2) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->neurokit2) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.17.0)
# Downloading neurokit2-0.2.10-py2.py3-none-any.whl (693 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.1/693.1 kB 15.2 MB/s eta 0:00:00
# Installing collected packages: neurokit2
# Successfully installed neurokit2-0.2.10
# Collecting biosppy
#   Downloading biosppy-2.2.3-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting bidict (from biosppy)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from biosppy) (3.13.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from biosppy) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biosppy) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from biosppy) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from biosppy) (1.14.1)
# Collecting shortuuid (from biosppy)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from biosppy) (1.17.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from biosppy) (1.4.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from biosppy) (4.11.0.86)
# Collecting pywavelets (from biosppy)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting mock (from biosppy)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->biosppy) (2.8.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->biosppy) (3.6.0)
# Downloading biosppy-2.2.3-py2.py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.0/158.0 kB 8.3 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 54.7 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Installing collected packages: shortuuid, pywavelets, mock, bidict, biosppy
# Successfully installed bidict-0.23.1 biosppy-2.2.3 mock-5.2.0 pywavelets-1.8.0 shortuuid-1.0.13
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# ERROR: Could not find a version that satisfies the requirement gzip (from versions: none)
# ERROR: No matching distribution found for gzip
# Collecting peakutils
#   Downloading PeakUtils-1.3.5-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from peakutils) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from peakutils) (1.14.1)
# Downloading PeakUtils-1.3.5-py3-none-any.whl (7.7 kB)
# Installing collected packages: peakutils
# Successfully installed peakutils-1.3.5
# PhysioNet Data Shape: torch.Size([340517, 1250])

# %%
# %%writefile NNModel.py
import torch
import torch.nn as nn
import torch.nn.functional as F

# Squeeze-and-Excitation (SE) Module
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool1d(1)  # Global Average Pooling
        self.fc1 = nn.Linear(channels, channels // reduction)
        self.fc2 = nn.Linear(channels // reduction, channels)

    def forward(self, x):
        batch, channels, _ = x.shape
        se = self.global_avg_pool(x).view(batch, channels)  # Global Avg Pool
        se = F.relu(self.fc1(se))  # First FC + ReLU
        se = F.softmax(self.fc2(se), dim=1)  # Second FC + Softmax
        se = se.view(batch, channels, 1)
        return x * se  # Scale the input

# Residual Block with SE Module
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=5):
        super(ResidualBlock, self).__init__()
        self.maxpool = nn.MaxPool1d(kernel_size=2)  # Add MaxPooling layer
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size, padding=kernel_size//2)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size, padding=kernel_size//2)
        self.se = SEBlock(out_channels)
        self.shortcut = nn.Conv1d(in_channels, out_channels, kernel_size=1) if in_channels != out_channels else nn.Identity()



    def forward(self, x):
        x= self.maxpool(x)  # Apply MaxPooling
        residual = self.shortcut(x)  # Skip connection
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.conv2(out)
        out = self.se(out)  # Apply SE Module
        out += residual  # Add Skip Connection
        return F.relu(out)

# Full Model: CNN + BiLSTM + FC
class ECGClassifier(nn.Module):
    def __init__(self, num_classes=5):
        super(ECGClassifier, self).__init__()

        # Initial Convolutional Layers
        self.conv1 = nn.Conv1d(1, 32, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(32)
        self.conv2 = nn.Conv1d(32, 32, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm1d(32)

        # Residual Blocks with SE Module (4 Blocks)
        self.resblock1 = ResidualBlock(32, 64)
        self.resblock2 = ResidualBlock(64, 96)
        self.resblock3 = ResidualBlock(96, 128)
        self.resblock4 = ResidualBlock(128, 160)

        # MaxPooling Layer
        self.maxpool = nn.MaxPool1d(kernel_size=2)

        # BiLSTM Layers
        self.lstm = nn.LSTM(160, 64, num_layers=2, bidirectional=True, batch_first=True)
        self.dropout1 = nn.Dropout(0.2)
        self.dropout2 = nn.Dropout(0.5)

        # Fully Connected Layers
        self.fc1 = nn.Linear(128, 64)  # BiLSTM outputs 64*2=128
        self.fc2 = nn.Linear(64, num_classes)

    def forward(self, x):
         # First Conv -> ReLU -> BatchNorm
        x = self.conv1(x)
        x = F.relu(x)
        x = self.bn1(x)

        # Second Conv -> ReLU -> BatchNorm
        x = self.conv2(x)
        x = F.relu(x)
        x = self.bn2(x)

        # Residual Blocks with SE Module
        x = self.resblock1(x)
        x = self.resblock2(x)
        x = self.resblock3(x)
        x = self.resblock4(x)

        # Max Pooling
        x = self.maxpool(x)

        # Reshape for LSTM (Batch, SeqLen, Features)
        x = x.permute(0, 2, 1)

        # BiLSTM
        x, _ = self.lstm(x)
        x = self.dropout1(x[:, -1, :])  # Take last LSTM output
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = self.fc2(x)

        return F.log_softmax(x, dim=1)  # Softmax for classification

# Create Model Instance
model = ECGClassifier(num_classes=5)

print(model)
# Out:
# Writing NNModel.py

# %%
# !pip install nbimporter

import torch
import torch.nn as nn
import torch.optim as optim
import nbimporter
from NNModel import ECGClassifier
import pickle
import gzip

# Load Pretraining Data (PhysioNet)
with gzip.open("pretraining_data.pkl.gz", "rb") as f:
    X_train, y_train = pickle.load(f)

# Convert to PyTorch Dataset
class ECGDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = X.unsqueeze(1)  # Add channel dimension
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Create DataLoader
batch_size = 64
train_dataset = ECGDataset(X_train, y_train)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Modify Model for Pretraining (Last FC Layer = 4 Classes)
class PretrainECGClassifier(ECGClassifier):
    def __init__(self):
        super(PretrainECGClassifier, self).__init__(num_classes=4)  # Change output classes to 4

# Initialize Model
model = PretrainECGClassifier()

# Use CUDA if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

# He Normal Initialization
def he_init(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv1d):
        nn.init.kaiming_normal_(m.weight, nonlinearity="relu")

model.apply(he_init)

# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Pretraining Loop
num_epochs = 3
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}")

# Save Pretrained Model with gzip and pickle
with gzip.open("pretrained_model.pth.gz", "wb") as f:
    pickle.dump(model.state_dict(), f)
print("Pretraining Complete. Model Saved as pretrained_model.pth.gz!")
# Out:
# Requirement already satisfied: nbimporter in /usr/local/lib/python3.11/dist-packages (0.3.4)
# ECGClassifier(
#   (conv1): Conv1d(1, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(32, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (resblock1): ResidualBlock(
#     (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (se): SEBlock(
#       (global_avg_pool): AdaptiveAvgPool1d(output_size=1)
#       (fc1): Linear(in_features=64, out_features=4, bias=True)
#       (fc2): Linear(in_features=4, out_features=64, bias=True)
#     )
#     (shortcut): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#   )
#   (resblock2): ResidualBlock(
#     (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv1d(64, 96, kernel_size=(5,), stride=(1,), padding=(2,))
#     (bn1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(96, 96, kernel_size=(5,), stride=(1,), padding=(2,))
#     (se): SEBlock(
#       (global_avg_pool): AdaptiveAvgPool1d(output_size=1)
#       (fc1): Linear(in_features=96, out_features=6, bias=True)
#       (fc2): Linear(in_features=6, out_features=96, bias=True)
#     )
#     (shortcut): Conv1d(64, 96, kernel_size=(1,), stride=(1,))
#   )
#   (resblock3): ResidualBlock(
#     (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv1d(96, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (se): SEBlock(
#       (global_avg_pool): AdaptiveAvgPool1d(output_size=1)
#       (fc1): Linear(in_features=128, out_features=8, bias=True)
#       (fc2): Linear(in_features=8, out_features=128, bias=True)
#     )
#     (shortcut): Conv1d(96, 128, kernel_size=(1,), stride=(1,))
#   )
#   (resblock4): ResidualBlock(
#     (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv1d(128, 160, kernel_size=(5,), stride=(1,), padding=(2,))
#     (bn1): BatchNorm1d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(160, 160, kernel_size=(5,), stride=(1,), padding=(2,))
#     (se): SEBlock(
#       (global_avg_pool): AdaptiveAvgPool1d(output_size=1)
#       (fc1): Linear(in_features=160, out_features=10, bias=True)
#       (fc2): Linear(in_features=10, out_features=160, bias=True)
#     )
#     (shortcut): Conv1d(128, 160, kernel_size=(1,), stride=(1,))
#   )
#   (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (lstm): LSTM(160, 64, num_layers=2, batch_first=True, bidirectional=True)
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )
# Using device: cuda
# Epoch 1/3, Loss: 1.0226958345994983
# Epoch 2/3, Loss: 1.0168445234884782
# Epoch 3/3, Loss: 1.016095334057341
# Pretraining Complete. Model Saved as pretrained_model.pth.gz!

# %%
# !zip -r training2017.zip data/training2017
# !zip -r mit-bih-arrhythmia-database.zip data/mit-bih-arrhythmia-database-1.0.0
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
#   adding: data/training2017/A04945.mat (deflated 30%)
#   adding: data/training2017/A02342.mat (deflated 39%)
#   adding: data/training2017/A00837.hea (deflated 13%)
#   adding: data/training2017/A07788.hea (deflated 14%)
#   adding: data/training2017/A04795.hea (deflated 12%)
#   adding: data/training2017/A03440.mat (deflated 48%)
#   adding: data/training2017/A04650.mat (deflated 42%)
#   adding: data/training2017/A06246.hea (deflated 12%)
#   adding: data/training2017/A02168.mat (deflated 23%)
#   adding: data/training2017/A08450.mat (deflated 32%)
#   adding: data/training2017/A02741.mat (deflated 46%)
#   adding: data/training2017/A07582.hea (deflated 13%)
#   adding: data/training2017/A04742.mat (deflated 24%)
#   adding: data/training2017/A01205.hea (deflated 11%)
#   adding: data/training2017/A00407.hea (deflated 12%)
#   adding: data/training2017/A01161.hea (deflated 14%)
#   adding: data/training2017/A02815.hea (deflated 14%)
#   adding: data/training2017/A06696.hea (deflated 12%)
#   adding: data/training2017/A06186.hea (deflated 12%)
#   adding: data/training2017/A01168.mat (deflated 38%)
#   adding: data/training2017/A04354.hea (deflated 13%)
#   adding: data/training2017/A07625.mat (deflated 31%)
#   adding: data/training2017/A07520.mat (deflated 42%)
#   adding: data/training2017/A05097.hea (deflated 13%)
#   adding: data/training2017/A04680.mat (deflated 35%)
#   adding: data/training2017/A04759.mat (deflated 46%)
#   adding: data/training2017/A04726.mat (deflated 35%)
#   adding: data/training2017/A08210.mat (deflated 29%)
#   adding: data/training2017/A01643.mat (deflated 51%)
#   adding: data/training2017/A04091.mat (deflated 36%)
#   adding: data/training2017/A08396.hea (deflated 13%)
#   adding: data/training2017/A06450.mat (deflated 44%)
#   adding: data/training2017/A01539.mat (deflated 40%)
#   adding: data/training2017/A03178.hea (deflated 17%)
#   adding: data/training2017/A04468.mat (deflated 32%)
#   adding: data/training2017/A06191.hea (deflated 15%)
#   adding: data/training2017/A07924.hea (deflated 12%)
#   adding: data/training2017/A03751.mat (deflated 36%)
#   adding: data/training2017/A03368.mat (deflated 42%)
#   adding: data/training2017/A00212.mat (deflated 36%)
#   adding: data/training2017/A02900.mat (deflated 26%)
#   adding: data/training2017/A06474.hea (deflated 13%)
#   adding: data/training2017/A07156.hea (deflated 12%)
#   adding: data/training2017/A00769.hea (deflated 13%)
#   adding: data/training2017/A04982.hea (deflated 12%)
#   adding: data/training2017/A08489.hea (deflated 12%)
#   adding: data/training2017/A01600.hea (deflated 14%)
#   adding: data/training2017/A03575.mat (deflated 39%)
#   adding: data/training2017/A06093.mat (deflated 30%)
#   adding: data/training2017/A04457.hea (deflated 14%)
#   adding: data/training2017/A05604.mat (deflated 41%)
#   adding: data/training2017/A06419.mat (deflated 50%)
#   adding: data/training2017/A04281.mat (deflated 37%)
#   adding: data/training2017/A07532.hea (deflated 11%)
#   adding: data/training2017/A01111.mat (deflated 47%)
#   adding: data/training2017/A02382.hea (deflated 13%)
#   adding: data/training2017/A04521.hea (deflated 13%)
#   adding: data/training2017/A06451.hea (deflated 13%)
#   adding: data/training2017/A08304.mat (deflated 41%)
#   adding: data/training2017/A05123.mat (deflated 54%)
#   adding: data/training2017/A00230.mat (deflated 36%)
#   adding: data/training2017/A00191.mat (deflated 39%)
#   adding: data/training2017/A03121.hea (deflated 13%)
#   adding: data/training2017/A00546.hea (deflated 12%)
#   adding: data/training2017/A04579.mat (deflated 36%)
#   adding: data/training2017/A03812.mat (deflated 30%)
#   adding: data/training2017/A06092.mat (deflated 23%)
#   adding: data/training2017/A05877.mat (deflated 42%)
#   adding: data/training2017/A04077.hea (deflated 12%)
#   adding: data/training2017/A03738.hea (deflated 12%)
#   adding: data/training2017/A03736.hea (deflated 14%)
#   adding: data/training2017/A06709.mat (deflated 42%)
#   adding: data/training2017/A04652.hea (deflated 13%)
#   adding: data/training2017/A00183.hea (deflated 12%)
#   adding: data/training2017/A04829.hea (deflated 13%)
#   adding: data/training2017/A03398.hea (deflated 10%)
#   adding: data/training2017/A04734.hea (deflated 14%)
#   adding: data/training2017/A08053.hea (deflated 13%)
#   adding: data/training2017/A02764.mat (deflated 33%)
#   adding: data/training2017/A08117.hea (deflated 16%)
#   adding: data/training2017/A07229.hea (deflated 13%)
#   adding: data/training2017/A00766.mat (deflated 39%)
#   adding: data/training2017/A03382.mat (deflated 41%)
#   adding: data/training2017/A04949.hea (deflated 13%)
#   adding: data/training2017/A05252.hea (deflated 14%)
#   adding: data/training2017/A00790.mat (deflated 45%)
#   adding: data/training2017/A03425.hea (deflated 12%)
#   adding: data/training2017/A03571.mat (deflated 45%)
#   adding: data/training2017/A04811.hea (deflated 13%)
#   adding: data/training2017/A02900.hea (deflated 13%)
#   adding: data/training2017/A00745.mat (deflated 34%)
#   adding: data/training2017/A02414.mat (deflated 34%)
#   adding: data/training2017/A00993.hea (deflated 13%)
#   adding: data/training2017/A00565.hea (deflated 13%)
#   adding: data/training2017/A06181.mat (deflated 41%)
#   adding: data/training2017/A00549.hea (deflated 14%)
#   adding: data/training2017/A05328.mat (deflated 37%)
#   adding: data/training2017/A05979.hea (deflated 14%)
#   adding: data/training2017/A03917.hea (deflated 12%)
#   adding: data/training2017/A02712.mat (deflated 48%)
#   adding: data/training2017/A08163.hea (deflated 10%)
#   adding: data/training2017/A07529.hea (deflated 14%)
#   adding: data/training2017/A01236.mat (deflated 50%)
#   adding: data/training2017/A00707.mat (deflated 22%)
#   adding: data/training2017/A06963.hea (deflated 12%)
#   adding: data/training2017/A04158.mat (deflated 38%)
#   adding: data/training2017/A01319.mat (deflated 51%)
#   adding: data/training2017/A03305.hea (deflated 13%)
#   adding: data/training2017/A03029.mat (deflated 46%)
#   adding: data/training2017/A01952.hea (deflated 13%)
#   adding: data/training2017/A03232.mat (deflated 51%)
#   adding: data/training2017/A07655.hea (deflated 16%)
#   adding: data/training2017/A00435.hea (deflated 12%)
#   adding: data/training2017/A03462.hea (deflated 11%)
#   adding: data/training2017/A06761.mat (deflated 40%)
#   adding: data/training2017/A04065.mat (deflated 45%)
#   adding: data/training2017/A05066.mat (deflated 35%)
#   adding: data/training2017/A01797.mat (deflated 51%)
#   adding: data/training2017/A08311.hea (deflated 13%)
#   adding: data/training2017/A07182.hea (deflated 12%)
#   adding: data/training2017/A02421.hea (deflated 13%)
#   adding: data/training2017/A06712.mat (deflated 41%)
#   adding: data/training2017/A03882.hea (deflated 12%)
#   adding: data/training2017/A04256.hea (deflated 13%)
#   adding: data/training2017/A02949.mat (deflated 49%)
#   adding: data/training2017/A07076.mat (deflated 37%)
#   adding: data/training2017/A04408.mat (deflated 45%)
#   adding: data/training2017/A03026.mat (deflated 36%)
#   adding: data/training2017/A04189.hea (deflated 13%)
#   adding: data/training2017/A07432.hea (deflated 11%)
#   adding: data/training2017/A03684.mat (deflated 45%)
#   adding: data/training2017/A04048.mat (deflated 59%)
#   adding: data/training2017/A01750.mat (deflated 25%)
#   adding: data/training2017/A00075.mat (deflated 31%)
#   adding: data/training2017/A03156.mat (deflated 33%)
#   adding: data/training2017/A02828.mat (deflated 39%)
#   adding: data/training2017/A01561.mat (deflated 48%)
#   adding: data/training2017/A03361.mat (deflated 47%)
#   adding: data/training2017/A00144.hea (deflated 13%)
#   adding: data/training2017/A08288.mat (deflated 32%)
#   adding: data/training2017/A06625.mat (deflated 41%)
#   adding: data/training2017/A06562.hea (deflated 13%)
#   adding: data/training2017/A02278.hea (deflated 12%)
#   adding: data/training2017/A00098.hea (deflated 12%)
#   adding: data/training2017/A04859.hea (deflated 14%)
#   adding: data/training2017/A02116.mat (deflated 26%)
#   adding: data/training2017/A07147.hea (deflated 12%)
#   adding: data/training2017/A04955.hea (deflated 13%)
#   adding: data/training2017/A01839.mat (deflated 49%)
#   adding: data/training2017/A07163.hea (deflated 12%)
#   adding: data/training2017/A06179.mat (deflated 42%)
#   adding: data/training2017/A07034.hea (deflated 15%)
#   adding: data/training2017/A03879.hea (deflated 12%)
#   adding: data/training2017/A00381.mat (deflated 42%)
#   adding: data/training2017/A05569.hea (deflated 12%)
#   adding: data/training2017/A08191.hea (deflated 12%)
#   adding: data/training2017/A07359.mat (deflated 41%)
#   adding: data/training2017/A00142.hea (deflated 12%)
#   adding: data/training2017/A05782.hea (deflated 11%)
#   adding: data/training2017/A04316.hea (deflated 12%)
#   adding: data/training2017/A02879.mat (deflated 46%)
#   adding: data/training2017/A01472.mat (deflated 39%)
#   adding: data/training2017/A05819.mat (deflated 44%)
#   adding: data/training2017/A03905.hea (deflated 13%)
#   adding: data/training2017/A04872.hea (deflated 12%)
#   adding: data/training2017/A08308.hea (deflated 12%)
#   adding: data/training2017/A02071.mat (deflated 53%)
#   adding: data/training2017/A01481.hea (deflated 12%)
#   adding: data/training2017/A00046.hea (deflated 13%)
#   adding: data/training2017/A02957.hea (deflated 12%)
#   adding: data/training2017/A02693.mat (deflated 45%)
#   adding: data/training2017/A00533.mat (deflated 57%)
#   adding: data/training2017/A01843.mat (deflated 42%)
#   adding: data/training2017/A03196.hea (deflated 10%)
#   adding: data/training2017/A06791.mat (deflated 42%)
#   adding: data/training2017/A03441.mat (deflated 43%)
#   adding: data/training2017/A04083.mat (deflated 38%)
#   adding: data/training2017/A08409.mat (deflated 28%)
#   adding: data/training2017/A04498.mat (deflated 36%)
#   adding: data/training2017/A00735.hea (deflated 12%)
#   adding: data/training2017/A03931.hea (deflated 13%)
#   adding: data/training2017/A05000.mat (deflated 49%)
#   adding: data/training2017/A04841.hea (deflated 13%)
#   adding: data/training2017/A03676.hea (deflated 12%)
#   adding: data/training2017/A04242.hea (deflated 14%)
#   adding: data/training2017/A01767.mat (deflated 42%)
#   adding: data/training2017/A06046.hea (deflated 11%)
#   adding: data/training2017/A08484.hea (deflated 13%)
#   adding: data/training2017/A01143.hea (deflated 12%)
#   adding: data/training2017/A01675.mat (deflated 39%)
#   adding: data/training2017/A00013.hea (deflated 11%)
#   adding: data/training2017/A01030.hea (deflated 12%)
#   adding: data/training2017/A07772.hea (deflated 16%)
#   adding: data/training2017/A08005.hea (deflated 12%)
#   adding: data/training2017/A07377.hea (deflated 13%)
#   adding: data/training2017/A02840.hea (deflated 13%)
#   adding: data/training2017/A05135.hea (deflated 12%)
#   adding: data/training2017/A03661.hea (deflated 13%)
#   adding: data/training2017/A03842.hea (deflated 12%)
#   adding: data/training2017/A08357.mat (deflated 46%)
#   adding: data/training2017/A03922.hea (deflated 14%)
#   adding: data/training2017/A05096.hea (deflated 13%)
#   adding: data/training2017/A03256.hea (deflated 16%)
#   adding: data/training2017/A06827.hea (deflated 12%)
#   adding: data/training2017/A08389.mat (deflated 44%)
#   adding: data/training2017/A00751.hea (deflated 12%)
#   adding: data/training2017/A05260.mat (deflated 44%)
#   adding: data/training2017/A07370.mat (deflated 44%)
#   adding: data/training2017/A07927.mat (deflated 39%)
#   adding: data/training2017/A07023.mat (deflated 40%)
#   adding: data/training2017/A03944.mat (deflated 35%)
#   adding: data/training2017/A05838.hea (deflated 13%)
#   adding: data/training2017/A06436.mat (deflated 44%)
#   adding: data/training2017/A03986.mat (deflated 36%)
#   adding: data/training2017/A02422.mat (deflated 54%)
#   adding: data/training2017/A00484.mat (deflated 53%)
#   adding: data/training2017/A05054.hea (deflated 13%)
#   adding: data/training2017/A06002.hea (deflated 13%)
#   adding: data/training2017/A04703.mat (deflated 48%)
#   adding: data/training2017/A03413.mat (deflated 38%)
#   adding: data/training2017/A00664.mat (deflated 30%)
#   adding: data/training2017/A02138.hea (deflated 10%)
#   adding: data/training2017/A03392.mat (deflated 34%)
#   adding: data/training2017/A04581.hea (deflated 12%)
#   adding: data/training2017/A04928.mat (deflated 42%)
#   adding: data/training2017/A06303.hea (deflated 13%)
#   adding: data/training2017/A04806.mat (deflated 39%)
#   adding: data/training2017/A08295.hea (deflated 14%)
#   adding: data/training2017/A04935.hea (deflated 13%)
#   adding: data/training2017/A02595.hea (deflated 12%)
#   adding: data/training2017/A02123.mat (deflated 35%)
#   adding: data/training2017/A02256.mat (deflated 47%)
#   adding: data/training2017/A08423.hea (deflated 13%)
#   adding: data/training2017/A07826.hea (deflated 12%)
#   adding: data/training2017/A03513.hea (deflated 13%)
#   adding: data/training2017/A08300.hea (deflated 16%)
#   adding: data/training2017/A05056.mat (deflated 33%)
#   adding: data/training2017/A08299.hea (deflated 12%)
#   adding: data/training2017/A05728.hea (deflated 13%)
#   adding: data/training2017/A07694.hea (deflated 18%)
#   adding: data/training2017/A06383.mat (deflated 46%)
#   adding: data/training2017/A08356.mat (deflated 49%)
#   adding: data/training2017/A04512.hea (deflated 12%)
#   adding: data/training2017/A06645.hea (deflated 12%)
#   adding: data/training2017/A06383.hea (deflated 13%)
#   adding: data/training2017/A04036.hea (deflated 14%)
#   adding: data/training2017/A04847.mat (deflated 48%)
#   adding: data/training2017/A04338.mat (deflated 45%)
#   adding: data/training2017/A01714.mat (deflated 25%)
#   adding: data/training2017/A00655.hea (deflated 10%)
#   adding: data/training2017/A05608.hea (deflated 14%)
#   adding: data/training2017/A06399.mat (deflated 51%)
#   adding: data/training2017/A03172.mat (deflated 31%)
#   adding: data/training2017/A00816.hea (deflated 10%)
#   adding: data/training2017/A04916.hea (deflated 12%)
#   adding: data/training2017/A05623.mat (deflated 43%)
#   adding: data/training2017/A04951.hea (deflated 13%)
#   adding: data/training2017/A01187.mat (deflated 40%)
#   adding: data/training2017/A05315.hea (deflated 13%)
#   adding: data/training2017/A02267.mat (deflated 42%)
#   adding: data/training2017/A01433.mat (deflated 40%)
#   adding: data/training2017/A02480.hea (deflated 12%)
#   adding: data/training2017/A04525.hea (deflated 12%)
#   adding: data/training2017/A02580.mat (deflated 50%)
#   adding: data/training2017/A00180.hea (deflated 13%)
#   adding: data/training2017/A00398.mat (deflated 45%)
#   adding: data/training2017/A05416.mat (deflated 43%)
#   adding: data/training2017/A06412.hea (deflated 12%)
#   adding: data/training2017/A00740.hea (deflated 14%)
#   adding: data/training2017/A05568.mat (deflated 48%)
#   adding: data/training2017/A00925.hea (deflated 13%)
#   adding: data/training2017/A02451.hea (deflated 13%)
#   adding: data/training2017/A03995.hea (deflated 13%)
#   adding: data/training2017/A08030.hea (deflated 15%)
#   adding: data/training2017/A03367.mat (deflated 32%)
#   adding: data/training2017/A03113.mat (deflated 35%)
#   adding: data/training2017/A02978.hea (deflated 12%)
#   adding: data/training2017/A05207.hea (deflated 11%)
#   adding: data/training2017/A07584.hea (deflated 14%)
#   adding: data/training2017/A02609.mat (deflated 37%)
#   adding: data/training2017/A03204.hea (deflated 15%)
#   adding: data/training2017/A05453.hea (deflated 15%)
#   adding: data/training2017/A05761.hea (deflated 12%)
#   adding: data/training2017/A04571.mat (deflated 47%)
#   adding: data/training2017/A06341.mat (deflated 38%)
#   adding: data/training2017/A04973.mat (deflated 53%)
#   adding: data/training2017/A07067.mat (deflated 39%)
#   adding: data/training2017/A02375.mat (deflated 37%)
#   adding: data/training2017/A06256.hea (deflated 12%)
#   adding: data/training2017/A00638.mat (deflated 51%)
#   adding: data/training2017/A04854.mat (deflated 56%)
#   adding: data/training2017/A00343.mat (deflated 32%)
#   adding: data/training2017/A07977.hea (deflated 12%)
#   adding: data/training2017/A01138.hea (deflated 15%)
#   adding: data/training2017/A02557.hea (deflated 12%)
#   adding: data/training2017/A07671.mat (deflated 35%)
#   adding: data/training2017/A02812.mat (deflated 43%)
#   adding: data/training2017/A02221.hea (deflated 16%)
#   adding: data/training2017/A07836.mat (deflated 36%)
#   adding: data/training2017/A03331.hea (deflated 13%)
#   adding: data/training2017/A07433.hea (deflated 11%)
#   adding: data/training2017/A01408.hea (deflated 12%)
#   adding: data/training2017/A04058.hea (deflated 12%)
#   adding: data/training2017/A08126.mat (deflated 44%)
#   adding: data/training2017/A00415.hea (deflated 12%)
#   adding: data/training2017/A01788.hea (deflated 12%)
#   adding: data/training2017/A04250.mat (deflated 42%)
#   adding: data/training2017/A05093.hea (deflated 12%)
#   adding: data/training2017/A06567.hea (deflated 10%)
#   adding: data/training2017/A01223.mat (deflated 43%)
#   adding: data/training2017/A00866.mat (deflated 33%)
#   adding: data/training2017/A07581.hea (deflated 12%)
#   adding: data/training2017/A03808.hea (deflated 16%)
#   adding: data/training2017/A05202.hea (deflated 12%)
#   adding: data/training2017/A02623.mat (deflated 39%)
#   adding: data/training2017/A04665.hea (deflated 12%)
#   adding: data/training2017/A02438.hea (deflated 12%)
#   adding: data/training2017/A01541.mat (deflated 42%)
#   adding: data/training2017/A07880.mat (deflated 39%)
#   adding: data/training2017/A06156.mat (deflated 42%)
#   adding: data/training2017/A06003.hea (deflated 13%)
#   adding: data/training2017/A07919.hea (deflated 12%)
#   adding: data/training2017/A02407.hea (deflated 12%)
#   adding: data/training2017/A01944.mat (deflated 46%)
#   adding: data/training2017/A05276.hea (deflated 13%)
#   adding: data/training2017/A06234.hea (deflated 14%)
#   adding: data/training2017/A07800.mat (deflated 36%)
#   adding: data/training2017/A03242.hea (deflated 12%)
#   adding: data/training2017/A07539.hea (deflated 13%)
#   adding: data/training2017/A02290.hea (deflated 14%)
#   adding: data/training2017/A06182.mat (deflated 35%)
#   adding: data/training2017/A00754.hea (deflated 15%)
#   adding: data/training2017/A03904.hea (deflated 15%)
#   adding: data/training2017/A05009.mat (deflated 43%)
#   adding: data/training2017/A04049.mat (deflated 45%)
#   adding: data/training2017/A06792.hea (deflated 13%)
#   adding: data/training2017/A06316.mat (deflated 33%)
#   adding: data/training2017/A04932.hea (deflated 11%)
#   adding: data/training2017/A08300.mat (deflated 51%)
#   adding: data/training2017/A08127.hea (deflated 12%)
#   adding: data/training2017/A03241.hea (deflated 16%)
#   adding: data/training2017/A00062.mat (deflated 39%)
#   adding: data/training2017/A05038.hea (deflated 11%)
#   adding: data/training2017/A07836.hea (deflated 12%)
#   adding: data/training2017/A03045.mat (deflated 36%)
#   adding: data/training2017/A00932.mat (deflated 35%)
#   adding: data/training2017/A08253.mat (deflated 37%)
#   adding: data/training2017/A02012.mat (deflated 37%)
#   adding: data/training2017/A04329.hea (deflated 12%)
#   adding: data/training2017/A00845.mat (deflated 44%)
#   adding: data/training2017/A03058.mat (deflated 47%)
#   adding: data/training2017/A04192.hea (deflated 13%)
#   adding: data/training2017/A02653.mat (deflated 52%)
#   adding: data/training2017/A02925.hea (deflated 12%)
#   adding: data/training2017/A02825.mat (deflated 38%)
#   adding: data/training2017/A02711.hea (deflated 12%)
#   adding: data/training2017/A02958.mat (deflated 52%)
#   adding: data/training2017/A06223.hea (deflated 15%)
#   adding: data/training2017/A05392.mat (deflated 52%)
#   adding: data/training2017/A00499.mat (deflated 38%)
#   adding: data/training2017/A08292.mat (deflated 39%)
#   adding: data/training2017/A00382.hea (deflated 13%)
#   adding: data/training2017/A07246.hea (deflated 14%)
#   adding: data/training2017/A05216.mat (deflated 22%)
#   adding: data/training2017/A01364.hea (deflated 13%)
#   adding: data/training2017/A08449.mat (deflated 43%)
#   adding: data/training2017/A03822.mat (deflated 41%)
#   adding: data/training2017/A00358.mat (deflated 53%)
#   adding: data/training2017/A08338.mat (deflated 45%)
#   adding: data/training2017/A01752.hea (deflated 12%)
#   adding: data/training2017/A06173.mat (deflated 48%)
#   adding: data/training2017/A07919.mat (deflated 40%)
#   adding: data/training2017/A00599.hea (deflated 13%)
#   adding: data/training2017/A02869.mat (deflated 45%)
#   adding: data/training2017/A00145.mat (deflated 40%)
#   adding: data/training2017/A00543.hea (deflated 13%)
#   adding: data/training2017/A03771.mat (deflated 44%)
#   adding: data/training2017/A07799.hea (deflated 13%)
#   adding: data/training2017/A06389.mat (deflated 43%)
#   adding: data/training2017/A05513.mat (deflated 33%)
#   adding: data/training2017/A00215.hea (deflated 13%)
#   adding: data/training2017/A04434.mat (deflated 34%)
#   adding: data/training2017/A07700.hea (deflated 13%)
#   adding: data/training2017/A02660.hea (deflated 12%)
#   adding: data/training2017/A02689.hea (deflated 10%)
#   adding: data/training2017/A04527.mat (deflated 42%)
#   adding: data/training2017/A07147.mat (deflated 37%)
#   adding: data/training2017/A08276.mat (deflated 47%)
#   adding: data/training2017/A02550.hea (deflated 10%)
#   adding: data/training2017/A06538.mat (deflated 39%)
#   adding: data/training2017/A01638.hea (deflated 12%)
#   adding: data/training2017/A07283.mat (deflated 51%)
#   adding: data/training2017/A02924.mat (deflated 38%)
#   adding: data/training2017/A06921.hea (deflated 12%)
#   adding: data/training2017/A03731.hea (deflated 12%)
#   adding: data/training2017/A00614.mat (deflated 39%)
#   adding: data/training2017/A01422.mat (deflated 51%)
#   adding: data/training2017/A00378.mat (deflated 39%)
#   adding: data/training2017/A05763.hea (deflated 13%)
#   adding: data/training2017/A04453.mat (deflated 41%)
#   adding: data/training2017/A04528.mat (deflated 34%)
#   adding: data/training2017/A01673.mat (deflated 46%)
#   adding: data/training2017/A03693.mat (deflated 30%)
#   adding: data/training2017/A04093.hea (deflated 12%)
#   adding: data/training2017/A07185.mat (deflated 38%)
#   adding: data/training2017/A01242.hea (deflated 12%)
#   adding: data/training2017/A03260.hea (deflated 11%)
#   adding: data/training2017/A01117.mat (deflated 34%)
#   adding: data/training2017/A06208.hea (deflated 12%)
#   adding: data/training2017/A00500.mat (deflated 44%)
#   adding: data/training2017/A08210.hea (deflated 12%)
#   adding: data/training2017/A00138.hea (deflated 13%)
#   adding: data/training2017/A06075.hea (deflated 13%)
#   adding: data/training2017/A01162.mat (deflated 41%)
#   adding: data/training2017/A02778.mat (deflated 38%)
#   adding: data/training2017/A02608.mat (deflated 67%)
#   adding: data/training2017/A07788.mat (deflated 40%)
#   adding: data/training2017/A04508.mat (deflated 41%)
#   adding: data/training2017/A08024.hea (deflated 16%)
#   adding: data/training2017/A00237.hea (deflated 13%)
#   adding: data/training2017/A04622.hea (deflated 13%)
#   adding: data/training2017/A07981.hea (deflated 10%)
#   adding: data/training2017/A05150.mat (deflated 49%)
#   adding: data/training2017/A08456.mat (deflated 26%)
#   adding: data/training2017/A07858.hea (deflated 13%)
#   adding: data/training2017/A05376.mat (deflated 52%)
#   adding: data/training2017/A04820.mat (deflated 44%)
#   adding: data/training2017/A07488.hea (deflated 12%)
#   adding: data/training2017/A04636.hea (deflated 12%)
#   adding: data/training2017/A07001.hea (deflated 13%)
#   adding: data/training2017/A00908.hea (deflated 12%)
#   adding: data/training2017/A01891.mat (deflated 41%)
#   adding: data/training2017/A02692.mat (deflated 40%)
#   adding: data/training2017/A04186.hea (deflated 11%)
#   adding: data/training2017/A04724.mat (deflated 39%)
#   adding: data/training2017/A03994.mat (deflated 61%)
#   adding: data/training2017/A01690.mat (deflated 36%)
#   adding: data/training2017/A04309.mat (deflated 37%)
#   adding: data/training2017/A06695.mat (deflated 44%)
#   adding: data/training2017/A00334.mat (deflated 59%)
#   adding: data/training2017/A02730.mat (deflated 32%)
#   adding: data/training2017/A03924.mat (deflated 52%)
#   adding: data/training2017/RECORDS (deflated 70%)
#   adding: data/training2017/A01990.mat (deflated 29%)
#   adding: data/training2017/A05305.hea (deflated 13%)
#   adding: data/training2017/A06378.hea (deflated 11%)
#   adding: data/training2017/A07432.mat (deflated 48%)
#   adding: data/training2017/A00711.mat (deflated 36%)
#   adding: data/training2017/A03765.hea (deflated 13%)
#   adding: data/training2017/A06649.mat (deflated 34%)
#   adding: data/training2017/A02892.hea (deflated 13%)
#   adding: data/training2017/A07863.hea (deflated 12%)
#   adding: data/training2017/A02486.hea (deflated 12%)
#   adding: data/training2017/A07774.mat (deflated 48%)
#   adding: data/training2017/A01485.hea (deflated 11%)
#   adding: data/training2017/A07427.mat (deflated 30%)
#   adding: data/training2017/A05410.hea (deflated 13%)
#   adding: data/training2017/A07713.mat (deflated 48%)
#   adding: data/training2017/A01948.hea (deflated 12%)
#   adding: data/training2017/A04046.mat (deflated 53%)
#   adding: data/training2017/A00701.mat (deflated 45%)
#   adding: data/training2017/A03479.mat (deflated 37%)
#   adding: data/training2017/A02528.mat (deflated 40%)
#   adding: data/training2017/A02295.hea (deflated 12%)
#   adding: data/training2017/A00929.mat (deflated 39%)
#   adding: data/training2017/A07806.mat (deflated 49%)
#   adding: data/training2017/A06563.hea (deflated 13%)
#   adding: data/training2017/A00520.hea (deflated 13%)
#   adding: data/training2017/A01218.mat (deflated 53%)
#   adding: data/training2017/A04289.hea (deflated 13%)
#   adding: data/training2017/A02779.hea (deflated 16%)
#   adding: data/training2017/A02816.hea (deflated 12%)
#   adding: data/training2017/A05974.mat (deflated 42%)
#   adding: data/training2017/A06582.mat (deflated 46%)
#   adding: data/training2017/A08391.hea (deflated 11%)
#   adding: data/training2017/A05075.hea (deflated 12%)
#   adding: data/training2017/A06593.mat (deflated 52%)
#   adding: data/training2017/A07950.mat (deflated 44%)
#   adding: data/training2017/A00082.hea (deflated 13%)
#   adding: data/training2017/A07467.mat (deflated 37%)
#   adding: data/training2017/A06446.hea (deflated 12%)
#   adding: data/training2017/A04772.mat (deflated 38%)
#   adding: data/training2017/A01786.mat (deflated 48%)
#   adding: data/training2017/A01043.hea (deflated 14%)
#   adding: data/training2017/A08227.hea (deflated 12%)
#   adding: data/training2017/A02633.hea (deflated 17%)
#   adding: data/training2017/A07342.hea (deflated 11%)
#   adding: data/training2017/A02010.mat (deflated 38%)
#   adding: data/training2017/A05302.mat (deflated 37%)
#   adding: data/training2017/A04479.mat (deflated 43%)
#   adding: data/training2017/A01695.hea (deflated 14%)
#   adding: data/training2017/A06985.hea (deflated 13%)
#   adding: data/training2017/A05309.mat (deflated 47%)
#   adding: data/training2017/A04559.hea (deflated 17%)
#   adding: data/training2017/A00147.hea (deflated 12%)
#   adding: data/training2017/A04899.mat (deflated 28%)
#   adding: data/training2017/A08508.mat (deflated 47%)
#   adding: data/training2017/A06693.mat (deflated 47%)
#   adding: data/training2017/A06516.hea (deflated 13%)
#   adding: data/training2017/A03922.mat (deflated 38%)
#   adding: data/training2017/A05802.hea (deflated 15%)
#   adding: data/training2017/A03015.hea (deflated 13%)
#   adding: data/training2017/A01113.hea (deflated 13%)
#   adding: data/training2017/A03365.hea (deflated 15%)
#   adding: data/training2017/A03100.mat (deflated 54%)
#   adding: data/training2017/A03159.hea (deflated 13%)
#   adding: data/training2017/A08281.mat (deflated 36%)
#   adding: data/training2017/A03675.mat (deflated 36%)
#   adding: data/training2017/A08181.mat (deflated 43%)
#   adding: data/training2017/A00982.hea (deflated 13%)
#   adding: data/training2017/A08043.mat (deflated 38%)
#   adding: data/training2017/A04863.mat (deflated 61%)
#   adding: data/training2017/A06586.mat (deflated 54%)
#   adding: data/training2017/A07656.hea (deflated 16%)
#   adding: data/training2017/A07963.mat (deflated 43%)
#   adding: data/training2017/A07309.mat (deflated 47%)
#   adding: data/training2017/A04664.mat (deflated 36%)
#   adding: data/training2017/A00007.mat (deflated 47%)
#   adding: data/training2017/A03846.mat (deflated 36%)
#   adding: data/training2017/A06324.hea (deflated 18%)
#   adding: data/training2017/A07844.mat (deflated 45%)
#   adding: data/training2017/A05275.hea (deflated 13%)
#   adding: data/training2017/A07159.hea (deflated 14%)
#   adding: data/training2017/A01792.hea (deflated 13%)
#   adding: data/training2017/A04956.mat (deflated 44%)
#   adding: data/training2017/A01059.hea (deflated 11%)
#   adding: data/training2017/A06729.hea (deflated 11%)
#   adding: data/training2017/A07251.hea (deflated 14%)
#   adding: data/training2017/A01322.mat (deflated 30%)
#   adding: data/training2017/A04006.hea (deflated 16%)
#   adding: data/training2017/A05005.hea (deflated 12%)
#   adding: data/training2017/A06684.hea (deflated 15%)
#   adding: data/training2017/A02147.hea (deflated 12%)
#   adding: data/training2017/A00069.hea (deflated 12%)
#   adding: data/training2017/A06088.mat (deflated 46%)
#   adding: data/training2017/A07781.hea (deflated 13%)
#   adding: data/training2017/A01374.hea (deflated 13%)
#   adding: data/training2017/A05256.mat (deflated 40%)
#   adding: data/training2017/A01860.hea (deflated 13%)
#   adding: data/training2017/A07499.hea (deflated 11%)
#   adding: data/training2017/A00361.mat (deflated 30%)
#   adding: data/training2017/A02418.hea (deflated 10%)
#   adding: data/training2017/A02797.hea (deflated 11%)
#   adding: data/training2017/A02259.hea (deflated 11%)
#   adding: data/training2017/A03208.mat (deflated 37%)
#   adding: data/training2017/A03619.mat (deflated 51%)
#   adding: data/training2017/A02777.mat (deflated 31%)
#   adding: data/training2017/A00671.hea (deflated 12%)
#   adding: data/training2017/A01913.mat (deflated 47%)
#   adding: data/training2017/A01913.hea (deflated 13%)
#   adding: data/training2017/A01387.mat (deflated 41%)
#   adding: data/training2017/A08156.hea (deflated 13%)
#   adding: data/training2017/A01375.mat (deflated 55%)
#   adding: data/training2017/A05284.hea (deflated 13%)
#   adding: data/training2017/A01152.mat (deflated 46%)
#   adding: data/training2017/A05002.mat (deflated 48%)
#   adding: data/training2017/A01278.hea (deflated 12%)
#   adding: data/training2017/A04145.hea (deflated 11%)
#   adding: data/training2017/A07801.hea (deflated 12%)
#   adding: data/training2017/A03270.mat (deflated 37%)
#   adding: data/training2017/A07878.hea (deflated 14%)
#   adding: data/training2017/A08016.hea (deflated 12%)
#   adding: data/training2017/A03089.hea (deflated 12%)
#   adding: data/training2017/A06422.mat (deflated 35%)
#   adding: data/training2017/A08298.mat (deflated 46%)
#   adding: data/training2017/A00544.mat (deflated 36%)
#   adding: data/training2017/A04163.hea (deflated 12%)
#   adding: data/training2017/A01293.mat (deflated 35%)
#   adding: data/training2017/A02208.mat (deflated 45%)
#   adding: data/training2017/A06615.hea (deflated 14%)
#   adding: data/training2017/A05687.mat (deflated 44%)
#   adding: data/training2017/A03037.hea (deflated 15%)
#   adding: data/training2017/A07507.hea (deflated 13%)
#   adding: data/training2017/A07859.hea (deflated 12%)
#   adding: data/training2017/A03425.mat (deflated 42%)
#   adding: data/training2017/A04745.hea (deflated 12%)
#   adding: data/training2017/A00380.hea (deflated 12%)
#   adding: data/training2017/A04516.mat (deflated 42%)
#   adding: data/training2017/A02543.hea (deflated 12%)
#   adding: data/training2017/A07413.hea (deflated 12%)
#   adding: data/training2017/A01639.hea (deflated 12%)
#   adding: data/training2017/A04162.mat (deflated 42%)
#   adding: data/training2017/A00465.hea (deflated 13%)
#   adding: data/training2017/A07078.mat (deflated 43%)
#   adding: data/training2017/A00623.mat (deflated 53%)
#   adding: data/training2017/A02088.hea (deflated 13%)
#   adding: data/training2017/A04178.mat (deflated 40%)
#   adding: data/training2017/A06931.hea (deflated 13%)
#   adding: data/training2017/A03010.hea (deflated 15%)
#   adding: data/training2017/A00198.hea (deflated 12%)
#   adding: data/training2017/A01110.hea (deflated 13%)
#   adding: data/training2017/A05579.mat (deflated 47%)
#   adding: data/training2017/A02520.hea (deflated 14%)
#   adding: data/training2017/A00380.mat (deflated 31%)
#   adding: data/training2017/A08170.mat (deflated 47%)
#   adding: data/training2017/A05051.hea (deflated 12%)
#   adding: data/training2017/A06056.mat (deflated 34%)
#   adding: data/training2017/A07391.mat (deflated 55%)
#   adding: data/training2017/A08233.hea (deflated 14%)
#   adding: data/training2017/A03272.mat (deflated 55%)
#   adding: data/training2017/A02268.hea (deflated 12%)
#   adding: data/training2017/A01734.mat (deflated 37%)
#   adding: data/training2017/A03108.hea (deflated 13%)
#   adding: data/training2017/A01232.hea (deflated 14%)
#   adding: data/training2017/A07339.hea (deflated 9%)
#   adding: data/training2017/A07921.hea (deflated 13%)
#   adding: data/training2017/A07580.hea (deflated 13%)
#   adding: data/training2017/A04099.hea (deflated 10%)
#   adding: data/training2017/A07478.hea (deflated 11%)
#   adding: data/training2017/A06710.mat (deflated 43%)
#   adding: data/training2017/A06999.hea (deflated 13%)
#   adding: data/training2017/A05044.mat (deflated 39%)
#   adding: data/training2017/A05069.hea (deflated 13%)
#   adding: data/training2017/A02442.hea (deflated 17%)
#   adding: data/training2017/A01756.hea (deflated 12%)
#   adding: data/training2017/A01415.hea (deflated 13%)
#   adding: data/training2017/A04320.mat (deflated 43%)
#   adding: data/training2017/A02464.hea (deflated 14%)
#   adding: data/training2017/A00952.mat (deflated 32%)
#   adding: data/training2017/A02937.hea (deflated 12%)
#   adding: data/training2017/A00210.mat (deflated 47%)
#   adding: data/training2017/A04273.hea (deflated 13%)
#   adding: data/training2017/A05996.mat (deflated 34%)
#   adding: data/training2017/A01508.mat (deflated 35%)
#   adding: data/training2017/A06304.hea (deflated 15%)
#   adding: data/training2017/A02908.mat (deflated 39%)
#   adding: data/training2017/A02223.hea (deflated 12%)
#   adding: data/training2017/A03031.hea (deflated 12%)
#   adding: data/training2017/A07364.mat (deflated 42%)
#   adding: data/training2017/A04469.hea (deflated 12%)
#   adding: data/training2017/A01766.mat (deflated 37%)
#   adding: data/training2017/A08203.mat (deflated 47%)
#   adding: data/training2017/A04282.hea (deflated 12%)
#   adding: data/training2017/A01370.hea (deflated 16%)
#   adding: data/training2017/A06518.mat (deflated 40%)
#   adding: data/training2017/A01798.hea (deflated 11%)
#   adding: data/training2017/A07749.hea (deflated 13%)
#   adding: data/training2017/A04652.mat (deflated 42%)
#   adding: data/training2017/A05170.hea (deflated 12%)
#   adding: data/training2017/A05092.hea (deflated 13%)
#   adding: data/training2017/A07419.mat (deflated 49%)
#   adding: data/training2017/A04824.hea (deflated 18%)
#   adding: data/training2017/A06619.mat (deflated 41%)
#   adding: data/training2017/A01907.hea (deflated 16%)
#   adding: data/training2017/A03522.hea (deflated 12%)
#   adding: data/training2017/A02694.hea (deflated 13%)
#   adding: data/training2017/A07344.mat (deflated 41%)
#   adding: data/training2017/A01263.mat (deflated 52%)
#   adding: data/training2017/A02644.mat (deflated 37%)
#   adding: data/training2017/A06993.hea (deflated 10%)
#   adding: data/training2017/A06581.hea (deflated 11%)
#   adding: data/training2017/A07134.mat (deflated 39%)
#   adding: data/training2017/A07697.mat (deflated 43%)
#   adding: data/training2017/A06193.hea (deflated 13%)
#   adding: data/training2017/A07710.hea (deflated 13%)
#   adding: data/training2017/A01662.mat (deflated 42%)
#   adding: data/training2017/A02257.mat (deflated 59%)
#   adding: data/training2017/A01805.hea (deflated 12%)
#   adding: data/training2017/A00246.hea (deflated 15%)
#   adding: data/training2017/A05966.hea (deflated 13%)
#   adding: data/training2017/A02551.mat (deflated 40%)
#   adding: data/training2017/A01900.mat (deflated 35%)
#   adding: data/training2017/A03970.mat (deflated 49%)
#   adding: data/training2017/A04327.mat (deflated 38%)
#   adding: data/training2017/A02577.hea (deflated 12%)
#   adding: data/training2017/A08453.mat (deflated 53%)
#   adding: data/training2017/A03196.mat (deflated 32%)
#   adding: data/training2017/A00921.hea (deflated 12%)
#   adding: data/training2017/A02296.hea (deflated 15%)
#   adding: data/training2017/A05087.hea (deflated 13%)
#   adding: data/training2017/A03580.hea (deflated 11%)
#   adding: data/training2017/A06654.hea (deflated 17%)
#   adding: data/training2017/A01056.hea (deflated 13%)
#   adding: data/training2017/A03973.hea (deflated 12%)
#   adding: data/training2017/A07449.hea (deflated 14%)
#   adding: data/training2017/A05580.hea (deflated 15%)
#   adding: data/training2017/A03106.hea (deflated 15%)
#   adding: data/training2017/A03236.mat (deflated 45%)
#   adding: data/training2017/A02400.mat (deflated 49%)
#   adding: data/training2017/A01292.hea (deflated 13%)
#   adding: data/training2017/A03833.hea (deflated 12%)
#   adding: data/training2017/A06086.hea (deflated 12%)
#   adding: data/training2017/A08305.mat (deflated 45%)
#   adding: data/training2017/A01609.hea (deflated 12%)
#   adding: data/training2017/A01226.mat (deflated 33%)
#   adding: data/training2017/A05821.mat (deflated 39%)
#   adding: data/training2017/A08422.mat (deflated 45%)
#   adding: data/training2017/A01497.mat (deflated 44%)
#   adding: data/training2017/A02045.hea (deflated 12%)
#   adding: data/training2017/A03276.mat (deflated 38%)
#   adding: data/training2017/A01076.mat (deflated 37%)
#   adding: data/training2017/A03188.mat (deflated 45%)
#   adding: data/training2017/A05770.hea (deflated 13%)
#   adding: data/training2017/A08041.mat (deflated 53%)
#   adding: data/training2017/A02911.hea (deflated 13%)
#   adding: data/training2017/A07814.mat (deflated 36%)
#   adding: data/training2017/A04287.mat (deflated 50%)
#   adding: data/training2017/A08298.hea (deflated 12%)
#   adding: data/training2017/A05069.mat (deflated 42%)
#   adding: data/training2017/A00732.mat (deflated 46%)
#   adding: data/training2017/A06318.mat (deflated 44%)
#   adding: data/training2017/A01302.mat (deflated 63%)
#   adding: data/training2017/A00187.mat (deflated 39%)
#   adding: data/training2017/A02872.mat (deflated 35%)
#   adding: data/training2017/A01596.mat (deflated 48%)
#   adding: data/training2017/A01120.mat (deflated 47%)
#   adding: data/training2017/A01760.mat (deflated 41%)
#   adding: data/training2017/A06241.hea (deflated 13%)
#   adding: data/training2017/A08110.hea (deflated 13%)
#   adding: data/training2017/A07039.hea (deflated 13%)
#   adding: data/training2017/A01467.hea (deflated 13%)
#   adding: data/training2017/A02947.hea (deflated 12%)
#   adding: data/training2017/A01089.mat (deflated 43%)
#   adding: data/training2017/A03203.mat (deflated 39%)
#   adding: data/training2017/A06219.mat (deflated 57%)
#   adding: data/training2017/A00869.mat (deflated 45%)
#   adding: data/training2017/A04912.mat (deflated 30%)
#   adding: data/training2017/A01983.mat (deflated 39%)
#   adding: data/training2017/A05132.mat (deflated 44%)
#   adding: data/training2017/A02128.hea (deflated 12%)
#   adding: data/training2017/A05578.mat (deflated 24%)
#   adding: data/training2017/A07242.hea (deflated 16%)
#   adding: data/training2017/A07806.hea (deflated 12%)
#   adding: data/training2017/A00965.mat (deflated 45%)
#   adding: data/training2017/A01747.hea (deflated 12%)
#   adding: data/training2017/A00995.hea (deflated 12%)
#   adding: data/training2017/A03470.mat (deflated 40%)
#   adding: data/training2017/A07398.mat (deflated 46%)
#   adding: data/training2017/A00106.mat (deflated 32%)
#   adding: data/training2017/A03350.mat (deflated 43%)
#   adding: data/training2017/A05919.hea (deflated 14%)
#   adding: data/training2017/A02776.mat (deflated 31%)
#   adding: data/training2017/A00298.hea (deflated 13%)
#   adding: data/training2017/A04217.hea (deflated 11%)
#   adding: data/training2017/A00104.hea (deflated 13%)
#   adding: data/training2017/A07040.hea (deflated 11%)
#   adding: data/training2017/A07106.hea (deflated 14%)
#   adding: data/training2017/A05094.hea (deflated 13%)
#   adding: data/training2017/A03195.hea (deflated 12%)
#   adding: data/training2017/A03992.mat (deflated 42%)
#   adding: data/training2017/A00206.mat (deflated 54%)
#   adding: data/training2017/A00443.mat (deflated 42%)
#   adding: data/training2017/A00128.mat (deflated 49%)
#   adding: data/training2017/A01311.mat (deflated 37%)
#   adding: data/training2017/A02590.hea (deflated 14%)
#   adding: data/training2017/A01033.hea (deflated 14%)
#   adding: data/training2017/A08109.mat (deflated 60%)
#   adding: data/training2017/A07812.hea (deflated 12%)
#   adding: data/training2017/A04321.hea (deflated 12%)
#   adding: data/training2017/A02533.hea (deflated 11%)
#   adding: data/training2017/A05762.mat (deflated 43%)
#   adding: data/training2017/A02223.mat (deflated 51%)
#   adding: data/training2017/A04582.mat (deflated 39%)
#   adding: data/training2017/A04303.hea (deflated 12%)
#   adding: data/training2017/A05582.mat (deflated 39%)
#   adding: data/training2017/A03287.mat (deflated 37%)
#   adding: data/training2017/A05434.mat (deflated 67%)
#   adding: data/training2017/A02108.mat (deflated 34%)
#   adding: data/training2017/A04452.mat (deflated 29%)
#   adding: data/training2017/A02003.mat (deflated 34%)
#   adding: data/training2017/A00622.hea (deflated 14%)
#   adding: data/training2017/A03396.mat (deflated 30%)
#   adding: data/training2017/A02275.mat (deflated 45%)
#   adding: data/training2017/A03434.mat (deflated 42%)
#   adding: data/training2017/A03294.hea (deflated 13%)
#   adding: data/training2017/A03840.mat (deflated 43%)
#   adding: data/training2017/A03249.mat (deflated 33%)
#   adding: data/training2017/A07666.mat (deflated 42%)
#   adding: data/training2017/A03826.hea (deflated 12%)
#   adding: data/training2017/A01949.mat (deflated 41%)
#   adding: data/training2017/A08324.mat (deflated 45%)
#   adding: data/training2017/A07724.hea (deflated 14%)
#   adding: data/training2017/A02028.hea (deflated 13%)
#   adding: data/training2017/A06121.hea (deflated 11%)
#   adding: data/training2017/A04355.mat (deflated 46%)
#   adding: data/training2017/A07457.hea (deflated 13%)
#   adding: data/training2017/A04565.hea (deflated 12%)
#   adding: data/training2017/A00684.hea (deflated 13%)
#   adding: data/training2017/A06140.hea (deflated 14%)
#   adding: data/training2017/A00224.hea (deflated 11%)
#   adding: data/training2017/A05393.mat (deflated 24%)
#   adding: data/training2017/A04124.hea (deflated 14%)
#   adding: data/training2017/A00289.hea (deflated 12%)
#   adding: data/training2017/A03654.mat (deflated 38%)
#   adding: data/training2017/A07298.hea (deflated 12%)
#   adding: data/training2017/A05539.hea (deflated 12%)
#   adding: data/training2017/A05119.hea (deflated 13%)
#   adding: data/training2017/A06416.hea (deflated 12%)
#   adding: data/training2017/A04744.mat (deflated 52%)
#   adding: data/training2017/A06893.hea (deflated 13%)
#   adding: data/training2017/A06375.mat (deflated 42%)
#   adding: data/training2017/A02086.hea (deflated 13%)
#   adding: data/training2017/A02467.mat (deflated 34%)
#   adding: data/training2017/A02172.hea (deflated 12%)
#   adding: data/training2017/A00918.hea (deflated 13%)
#   adding: data/training2017/A00219.hea (deflated 13%)
#   adding: data/training2017/A07867.mat (deflated 34%)
#   adding: data/training2017/A06505.mat (deflated 49%)
#   adding: data/training2017/A07940.mat (deflated 50%)
#   adding: data/training2017/A01355.mat (deflated 37%)
#   adding: data/training2017/A04959.mat (deflated 47%)
#   adding: data/training2017/A04436.mat (deflated 41%)
#   adding: data/training2017/A07517.hea (deflated 12%)
#   adding: data/training2017/A08228.mat (deflated 42%)
#   adding: data/training2017/A02892.mat (deflated 41%)
#   adding: data/training2017/A05001.hea (deflated 13%)
#   adding: data/training2017/A05814.mat (deflated 48%)
#   adding: data/training2017/A02373.mat (deflated 29%)
#   adding: data/training2017/A00566.mat (deflated 42%)
#   adding: data/training2017/A03066.mat (deflated 52%)
#   adding: data/training2017/A05371.hea (deflated 13%)
#   adding: data/training2017/A07333.mat (deflated 53%)
#   adding: data/training2017/A05792.mat (deflated 47%)
#   adding: data/training2017/A04741.hea (deflated 12%)
#   adding: data/training2017/A03424.mat (deflated 53%)
#   adding: data/training2017/A02726.mat (deflated 41%)
#   adding: data/training2017/A04760.mat (deflated 44%)
#   adding: data/training2017/A06027.mat (deflated 34%)
#   adding: data/training2017/A05731.mat (deflated 44%)
#   adding: data/training2017/A02706.mat (deflated 57%)
#   adding: data/training2017/A00274.hea (deflated 13%)
#   adding: data/training2017/A04368.mat (deflated 52%)
#   adding: data/training2017/A07021.hea (deflated 13%)
#   adding: data/training2017/A02097.mat (deflated 39%)
#   adding: data/training2017/A05175.hea (deflated 12%)
#   adding: data/training2017/A01304.hea (deflated 14%)
#   adding: data/training2017/A05115.mat (deflated 35%)
#   adding: data/training2017/A01515.mat (deflated 32%)
#   adding: data/training2017/A07149.hea (deflated 12%)
#   adding: data/training2017/A01000.mat (deflated 36%)
#   adding: data/training2017/A01731.hea (deflated 12%)
#   adding: data/training2017/A07926.mat (deflated 46%)
#   adding: data/training2017/A01742.hea (deflated 14%)
#   adding: data/training2017/A03069.mat (deflated 42%)
#   adding: data/training2017/A07396.mat (deflated 42%)
#   adding: data/training2017/A01589.mat (deflated 44%)
#   adding: data/training2017/A07308.mat (deflated 66%)
#   adding: data/training2017/A05590.mat (deflated 47%)
#   adding: data/training2017/A05833.hea (deflated 12%)
#   adding: data/training2017/A03410.hea (deflated 12%)
#   adding: data/training2017/A00639.mat (deflated 34%)
#   adding: data/training2017/A00831.mat (deflated 45%)
#   adding: data/training2017/A01191.hea (deflated 14%)
#   adding: data/training2017/A01244.hea (deflated 13%)
#   adding: data/training2017/A02854.hea (deflated 14%)
#   adding: data/training2017/A07098.mat (deflated 38%)
#   adding: data/training2017/A06184.hea (deflated 13%)
#   adding: data/training2017/A04514.hea (deflated 13%)
#   adding: data/training2017/A02952.mat (deflated 49%)
#   adding: data/training2017/A06119.mat (deflated 38%)
#   adding: data/training2017/A04265.mat (deflated 46%)
#   adding: data/training2017/A02493.hea (deflated 14%)
#   adding: data/training2017/A08309.mat (deflated 35%)
#   adding: data/training2017/A06935.hea (deflated 11%)
#   adding: data/training2017/A06471.hea (deflated 13%)
#   adding: data/training2017/A04822.hea (deflated 14%)
#   adding: data/training2017/A03791.mat (deflated 41%)
#   adding: data/training2017/A02037.mat (deflated 41%)
#   adding: data/training2017/A05152.mat (deflated 44%)
#   adding: data/training2017/A07518.mat (deflated 35%)
#   adding: data/training2017/A05208.mat (deflated 43%)
#   adding: data/training2017/A02843.mat (deflated 51%)
#   adding: data/training2017/A06799.mat (deflated 36%)
#   adding: data/training2017/A02976.hea (deflated 12%)
#   adding: data/training2017/A00397.hea (deflated 10%)
#   adding: data/training2017/A00903.mat (deflated 57%)
#   adding: data/training2017/A06351.mat (deflated 27%)
#   adding: data/training2017/A03451.mat (deflated 41%)
#   adding: data/training2017/A05010.hea (deflated 14%)
#   adding: data/training2017/A03761.mat (deflated 36%)
#   adding: data/training2017/A01401.hea (deflated 14%)
#   adding: data/training2017/A01005.mat (deflated 33%)
#   adding: data/training2017/A01867.mat (deflated 41%)
#   adding: data/training2017/A03704.hea (deflated 12%)
#   adding: data/training2017/A00864.hea (deflated 14%)
#   adding: data/training2017/A05687.hea (deflated 16%)
#   adding: data/training2017/A08386.mat (deflated 48%)
#   adding: data/training2017/A06286.mat (deflated 38%)
#   adding: data/training2017/A04801.mat (deflated 62%)
#   adding: data/training2017/A05435.hea (deflated 12%)
#   adding: data/training2017/A04448.mat (deflated 32%)
#   adding: data/training2017/A01987.hea (deflated 14%)
#   adding: data/training2017/A05841.hea (deflated 14%)
#   adding: data/training2017/A06928.mat (deflated 32%)
#   adding: data/training2017/A06522.mat (deflated 43%)
#   adding: data/training2017/A06976.hea (deflated 12%)
#   adding: data/training2017/A00708.hea (deflated 12%)
# ...
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1152842.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1241027.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2072910.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1002755.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1222825.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1211648.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1030109.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2012233.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2171401.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1142002.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2052757.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2082858.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2032446.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1150055.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140000.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2330025.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2051454.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1052907.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2232358.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140120.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1111541.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1010148.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1110241.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2322320.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2192211.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1082420.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2322334.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1091401.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2170123.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2072714.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2191900.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1001103.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2070045.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1111153.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2190522.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1081055.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2010752.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2342317.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1061227.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2002831.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2092910.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1020230.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2171530.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2070656.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1240443.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2032202.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2192855.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1002513.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2131730.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1182953.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1112702.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2031502.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140435.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140356.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2131505.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1080813.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1060757.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2321151.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2011814.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1180923.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2092833.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1082005.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2332223.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2031314.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2052430.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2030500.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1210106.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2070241.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1080451.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2170651.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2280050.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2192609.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2330943.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2231351.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140339.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1072552.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2002918.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1052808.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1090013.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1210333.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2170705.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1161637.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2021845.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2282137.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1091921.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2312011.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1152705.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2122846.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1090336.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2330218.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2022558.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2140325.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2142752.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1042910.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1121140.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1040617.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1002609.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2051603.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2090550.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2012016.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2150255.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2201041.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2021822.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2032325.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1092803.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2320151.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2051522.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2122645.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2130339.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2341401.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1140926.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2331802.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1020112.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1042651.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1110352.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2230935.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1141137.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1040552.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1090527.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2231339.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2310002.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1060137.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1212432.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2010853.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2131448.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2280019.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2300012.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2280038.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2192443.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1130420.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2102915.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2000538.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2191957.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2170612.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2322231.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2300926.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1121249.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2330011.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2152730.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1092828.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1190238.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2090047.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2032651.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2341426.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1020935.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2321509.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2102033.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2012620.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1152128.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2201810.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2132651.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2170033.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2012803.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2122421.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1182325.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2231755.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2142317.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2210000.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2021224.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1050757.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2100656.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1160131.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2120005.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1070044.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2022126.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/2022110.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1090446.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/samples/1192005.xws (stored 0%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/mitdbdir/intro.htm (deflated 63%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/207.dat (deflated 26%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/215.xws (deflated 16%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/122.dat (deflated 29%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/217.hea (deflated 25%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/117.at_ (deflated 45%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/116.atr (deflated 51%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/102.xws (deflated 16%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/209.atr (deflated 44%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/103.xws (deflated 16%)
#   adding: data/mit-bih-arrhythmia-database-1.0.0/208.dat (deflated 25%)
